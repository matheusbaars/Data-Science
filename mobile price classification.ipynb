# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
#import plotly.express as px

# %%
pd.options.display.max_columns = None #para retirar limite de colunas do pandas
pd.options.display.max_rows = None #para retirar limite de linhas do pandas

# %%
dataset = pd.read_csv('train.csv')

# %%
dataset.head(5)

# %%
dataset.describe()

# %%
dataset.isna().sum()

# %% [markdown]
# # Não existem valores nulos

# %%
dataset["price_range"].unique()
# Out:
# array([1, 2, 3, 0])

# %%
dataset["price_range"].value_counts()
# Out:
# 3    500
# 2    500
# 1    500
# 0    500
# Name: price_range, dtype: int64

# %%
plt.figure(figsize=(20, 10))
# Store heatmap object in a variable to easily access it when you want to include more features (such as title).
# Set the range of values to be displayed on the colormap from -1 to 1, and set the annotation to True to display the correlation values on the heatmap.
heatmap = sns.heatmap(dataset.corr(), vmin=-1, vmax=1, annot=True)
# Give a title to the heatmap. Pad defines the distance of the title from the top of the heatmap.
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':16}, pad=16);

# %%
features = ['battery_power', 'blue', 'fc', 'int_memory', 'mobile_wt', 'pc', 'px_height', 'px_width', 'ram',
           'sc_h', 'talk_time', 'three_g', 'touch_screen']

# %%
Data = dataset[features]

# %%
Target = dataset['price_range']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(Data, Target, test_size=0.2, random_state=100)

# %%
dtc = tree.DecisionTreeClassifier()
dtc = dtc.fit(X_train, Y_train)

# %%
y_pred = dtc.predict(X_test)

# %%
accuracy = accuracy_score(Y_test,y_pred)*100
print(accuracy)
# Out:
# 78.5

# %% [markdown]
# ## encontrando o melhor nível

# %%
for i in range(1, 50):
    dtc = tree.DecisionTreeClassifier(max_depth=i, min_samples_leaf=5, random_state=100)
    dtc = dtc.fit(X_train, Y_train)
    y_pred = dtc.predict(X_test)
    accuracy = accuracy_score(Y_test,y_pred)*100
    print('Nível = {} | Acurácia = {}'.format(i, accuracy))
# Out:
# Nível = 1 | Acurácia = 51.24999999999999
# Nível = 2 | Acurácia = 73.5
# Nível = 3 | Acurácia = 73.5
# Nível = 4 | Acurácia = 79.75
# Nível = 5 | Acurácia = 80.5
# Nível = 6 | Acurácia = 80.25
# Nível = 7 | Acurácia = 80.25
# Nível = 8 | Acurácia = 81.25
# Nível = 9 | Acurácia = 82.75
# Nível = 10 | Acurácia = 82.75
# Nível = 11 | Acurácia = 82.75
# Nível = 12 | Acurácia = 82.75
# Nível = 13 | Acurácia = 82.75
# Nível = 14 | Acurácia = 82.75
# Nível = 15 | Acurácia = 82.75
# Nível = 16 | Acurácia = 82.75
# Nível = 17 | Acurácia = 82.75
# Nível = 18 | Acurácia = 82.75
# Nível = 19 | Acurácia = 82.75
# Nível = 20 | Acurácia = 82.75
# Nível = 21 | Acurácia = 82.75
# Nível = 22 | Acurácia = 82.75
# Nível = 23 | Acurácia = 82.75
# Nível = 24 | Acurácia = 82.75
# Nível = 25 | Acurácia = 82.75
# Nível = 26 | Acurácia = 82.75
# Nível = 27 | Acurácia = 82.75
# Nível = 28 | Acurácia = 82.75
# Nível = 29 | Acurácia = 82.75
# Nível = 30 | Acurácia = 82.75
# Nível = 31 | Acurácia = 82.75
# ...
